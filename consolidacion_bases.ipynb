# %%
ubicacion = "C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Forecast Error (Python)/OEM/Base Forecast Error"

# %%
import pandas as pd
import os
import getpass
usuario = getpass.getuser()

# %%
dfs=[]

# %%
mara = pd.read_csv("C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Bases Indicadores en CSV 2025-03/MARA_R3.csv")
# Out:
# C:\Users\lravlic\AppData\Local\Temp\ipykernel_19200\363360223.py:1: DtypeWarning: Columns (0,3,4,5,6,7,8,11,12,13,14,15,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   mara = pd.read_csv("C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Bases Indicadores en CSV 2025-03/MARA_R3.csv")

# %%
mara.drop_duplicates(subset='Material_R3', inplace=True)

# %%
mara['Material_R3'] = mara['Material_R3'].astype('str')

# %%
import pandas as pd
from tkinter import Tk
from tkinter.filedialog import askopenfilename

# Ocultar la ventana principal de Tkinter
Tk().withdraw()

# Abrir el explorador de archivos para seleccionar un archivo
file_path = askopenfilename(title="Seleccionar archivo de Excel", 
                            filetypes=[("Archivos de Excel", "*.xlsx"), 
                                       ("Todos los archivos", "*.*")])

# Verificar si se seleccionó un archivo
if file_path:
    # Leer el archivo seleccionado
    df = pd.read_excel(file_path)
    print("Archivo cargado exitosamente.")
else:
    print("No se seleccionó ningún archivo.")
# Out:
# Archivo cargado exitosamente.

# %%
df_cruce = df.merge(mara[['Material_R3','Sector_dsc']], left_on='UE_2', right_on='Material_R3', how='left')

# %%
df_cruce[df_cruce['Sector_dsc']=='Mazda']['Total instock'].value_counts()
# Out:
# Total instock
# 0    75560
# 4    14834
# 3      357
# 2      290
# 1      273
# Name: count, dtype: int64

# %%
Total instock
0    75732
4    14690
3      349
2      272
1      271
Name: count, dtype: int64

# %%
# condicion = df_cruce['Sector_dsc'].isin(['Subaru', 'DFSK', 'GEELY', 'Geely'])

# # Reemplazar los valores de 'Total instock' con 5 cuando se cumpla la condición
# df_cruce.loc[condicion, 'Total instock'] = 4

# %%
df_2 = pd.read_parquet("C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Forecast Error (Python)/OEM/Base Forecast Error/consolidado_fc_error.parquet")

# %%
df_2['Mes'].value_counts()
# Out:
# Mes
# 2025-03-07    482300
# 2025-02-07    481095
# 2024-12-06    377916
# 2025-01-09    363770
# 2024-11-08    327370
# 2024-08-06    219585
# 2024-10-07    211146
# 2024-09-04    209894
# 2024-06-04    165997
# 2024-07-02    165910
# 2024-05-07    162786
# 2024-04-29    161101
# 2024-03-01    160176
# 2024-01-02    157310
# 2024-01-01    156656
# 2023-12-01    156644
# 2023-11-01    154271
# 2023-10-01    128165
# 2023-09-01    127498
# 2023-08-01    126801
# 2023-02-01    105946
# 2023-01-01    105913
# 2023-03-01    105345
# 2023-04-01    104282
# 2023-05-01    102886
# 2023-06-01    102630
# 2023-07-01    102084
# Name: count, dtype: int64

# %%
df_2 = df_2[df_2['Mes']!='2025-03-07']

# %%
df_2['Mes'].value_counts()
# Out:
# Mes
# 2025-02-07    481095
# 2024-12-06    377916
# 2025-01-09    363770
# 2024-11-08    327370
# 2024-08-06    219585
# 2024-10-07    211146
# 2024-09-04    209894
# 2024-06-04    165997
# 2024-07-02    165910
# 2024-05-07    162786
# 2024-04-29    161101
# 2024-03-01    160176
# 2024-01-02    157310
# 2024-01-01    156656
# 2023-12-01    156644
# 2023-11-01    154271
# 2023-10-01    128165
# 2023-09-01    127498
# 2023-08-01    126801
# 2023-02-01    105946
# 2023-01-01    105913
# 2023-03-01    105345
# 2023-04-01    104282
# 2023-05-01    102886
# 2023-06-01    102630
# 2023-07-01    102084
# Name: count, dtype: int64

# %%
df_consolidado_2 = pd.concat([df_2, df_cruce])

# %%
df_consolidado_2['Mes'].value_counts()
# Out:
# Mes
# 2025-03-19             482300
# 2025-02-07 00:00:00    481095
# 2024-12-06 00:00:00    377916
# 2025-01-09 00:00:00    363770
# 2024-11-08 00:00:00    327370
# 2024-08-06 00:00:00    219585
# 2024-10-07 00:00:00    211146
# 2024-09-04 00:00:00    209894
# 2024-06-04 00:00:00    165997
# 2024-07-02 00:00:00    165910
# 2024-05-07 00:00:00    162786
# 2024-04-29 00:00:00    161101
# 2024-03-01 00:00:00    160176
# 2024-01-02 00:00:00    157310
# 2024-01-01 00:00:00    156656
# 2023-12-01 00:00:00    156644
# 2023-11-01 00:00:00    154271
# 2023-10-01 00:00:00    128165
# 2023-09-01 00:00:00    127498
# 2023-08-01 00:00:00    126801
# 2023-02-01 00:00:00    105946
# 2023-01-01 00:00:00    105913
# 2023-03-01 00:00:00    105345
# 2023-04-01 00:00:00    104282
# 2023-05-01 00:00:00    102886
# 2023-06-01 00:00:00    102630
# 2023-07-01 00:00:00    102084
# Name: count, dtype: int64

# %%
df_consolidado_2.Mes = pd.to_datetime(df_consolidado_2['Mes'])

# %%
df_consolidado_2['Input'] = df_consolidado_2['Input'].astype(str)

# %%
df_consolidado_2.Mes.value_counts()
# Out:
# Mes
# 2025-03-19    482300
# 2025-02-07    481095
# 2024-12-06    377916
# 2025-01-09    363770
# 2024-11-08    327370
# 2024-08-06    219585
# 2024-10-07    211146
# 2024-09-04    209894
# 2024-06-04    165997
# 2024-07-02    165910
# 2024-05-07    162786
# 2024-04-29    161101
# 2024-03-01    160176
# 2024-01-02    157310
# 2024-01-01    156656
# 2023-12-01    156644
# 2023-11-01    154271
# 2023-10-01    128165
# 2023-09-01    127498
# 2023-08-01    126801
# 2023-02-01    105946
# 2023-01-01    105913
# 2023-03-01    105345
# 2023-04-01    104282
# 2023-05-01    102886
# 2023-06-01    102630
# 2023-07-01    102084
# Name: count, dtype: int64

# %%
df_consolidado_2.to_parquet("C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Forecast Error (Python)/OEM/Base Forecast Error/consolidado_fc_error.parquet")

# %%
df_2 = df_2[~df_2['Mes'].isin(['2024-09-04', '2024-08-06'])]

# %%
df_2 = df_2.merge(mara[['Material_R3','Sector_dsc']], left_on='UE_2', right_on='Material_R3', how='left')

# %%
df_2[df_2['Sector_dsc_y']=='Subaru'][['Mes', 'Total instock']]
# Out:
#                Mes  Total instock
# 1392    2024-09-04              4
# 1393    2024-09-04              4
# 1394    2024-09-04              4
# 1395    2024-09-04              4
# 1396    2024-09-04              4
# ...            ...            ...
# 2928063 2024-08-06              0
# 2928064 2024-08-06              0
# 2928065 2024-08-06              0
# 2928066 2024-08-06              0
# 2928067 2024-08-06              0
#
# [74226 rows x 2 columns]

# %%
df_2 =

# %%
df_consolidado_2.Mes.value_counts()
# Out:
# Mes
# 2024-08-06    219585
# 2024-10-07    211146
# 2024-09-04    209894
# 2024-06-04    165997
# 2024-07-02    165910
# 2024-05-07    162786
# 2024-04-29    161101
# 2024-03-01    160176
# 2024-01-02    157310
# 2024-01-01    156656
# 2023-12-01    156644
# 2023-11-01    154271
# 2023-10-01    128165
# 2023-09-01    127498
# 2023-08-01    126801
# 2023-02-01    105946
# 2023-01-01    105913
# 2023-03-01    105345
# 2023-04-01    104282
# 2023-05-01    102886
# 2023-06-01    102630
# 2023-07-01    102084
# Name: count, dtype: int64

# %%
df_consolidado = pd.concat([df, df_2], ignore_index=True)

# %%
df_consolidado.Mes.value_counts()
# Out:
# Mes
# 2025-03-07             482300
# 2025-02-07 00:00:00    481095
# 2024-12-06 00:00:00    377916
# 2025-01-09 00:00:00    363770
# 2024-11-08 00:00:00    327370
# 2024-08-06 00:00:00    219585
# 2024-10-07 00:00:00    211146
# 2024-09-04 00:00:00    209894
# 2024-06-04 00:00:00    165997
# 2024-07-02 00:00:00    165910
# 2024-05-07 00:00:00    162786
# 2024-04-29 00:00:00    161101
# 2024-03-01 00:00:00    160176
# 2024-01-02 00:00:00    157310
# 2024-01-01 00:00:00    156656
# 2023-12-01 00:00:00    156644
# 2023-11-01 00:00:00    154271
# 2023-10-01 00:00:00    128165
# 2023-09-01 00:00:00    127498
# 2023-08-01 00:00:00    126801
# 2023-02-01 00:00:00    105946
# 2023-01-01 00:00:00    105913
# 2023-03-01 00:00:00    105345
# 2023-04-01 00:00:00    104282
# 2023-05-01 00:00:00    102886
# 2023-06-01 00:00:00    102630
# 2023-07-01 00:00:00    102084
# Name: count, dtype: int64

# %%
df_consolidado['Mes'] = pd.to_datetime(df_consolidado['Mes'], errors='coerce')

# Convertir la columna 'Input' a string (o cualquier otro tipo que consideres apropiado)
df_consolidado['Input'] = df_consolidado['Input'].astype(str)

# %%
df_consolidado.to_parquet("C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Forecast Error (Python)/OEM/Base Forecast Error/consolidado_fc_error.parquet")

# %%
df_consolidado.columns
# Out:
# Index(['ID2', 'Periodo', 'UE_2', 'fc', 'fc_anas', 'Venta', 'Prom.',
#        'Total instock', 'MAPE_AJUSTADO', 'ERP', 'ERN', 'MAPE_ANASTASIA',
#        'ERP_ANASTASIA', 'ERN_ANASTASIA', 'WMAPE', 'WMAPE.1', 'Mes',
#        'Costo Promedio Ponderado', 'Costo de Venta', 'Forecast en Costo',
#        'MAPE Costo', 'ERP Costo', 'ERN Costo', 'WMAPE Costo', 'Input'],
#       dtype='object')

# %%
import pandas as pd
df = pd.read_parquet('consolidado_fc_error.parquet')

# %%
df_2 = pd.read_excel('C:/Users/lravlic/Inchcape/Planificación y Compras Chile - Documentos/Planificación y Compras KPI-Reportes/Forecast Error (Python)/OEM/Base Forecast Error/Forecast Error OEM Febrero 2025.xlsx')

# %%
df_2['Input'] = df_2['Input'].astype('str')

# %%
df_2.to_parquet('consolidado_2.parquet')

# %%
df_2 = pd.read_parquet('consolidado_2.parquet')

# %%
df_2['Mes'] = pd.to_datetime(df_2['Mes'])

# %%
df_final.dtypes
# Out:
# ID2                                 object
# Periodo                             object
# UE_2                                object
# fc                                 float64
# fc_anas                            float64
# Venta                              float64
# Prom.                              float64
# Total instock                        int64
# MAPE_AJUSTADO                      float64
# ERP                                float64
# ERN                                float64
# MAPE_ANASTASIA                     float64
# ERP_ANASTASIA                      float64
# ERN_ANASTASIA                      float64
# WMAPE                              float64
# WMAPE.1                            float64
# Mes                         datetime64[ns]
# Costo Promedio Ponderado           float64
# Costo de Venta                     float64
# Forecast en Costo                  float64
# MAPE Costo                         float64
# ERP Costo                          float64
# ...

# %%
df_2
# Out:
#                             ID2 Periodo            UE_2          fc  \
# 0       0000000190-OP1CL CES 01     N-1  0000000190-OP1     0.00000
# 1       0000000190-OP1CL CES 01     N-4  0000000190-OP1     0.00000
# 2        0000000229CPZCL CES 01     N-1   0000000229CPZ     0.00000
# 3           0000000244CL CES 01     N-1      0000000244     0.00000
# 4           0000000244CL CES 01     N-4      0000000244     0.00000
# ...                         ...     ...             ...         ...
# 219580       ZZJ118110CL CES 01     N-1       ZZJ118110    40.11290
# 219581       ZZJ118110CL CES 01     N-4       ZZJ118110    33.97096
# 219582       ZZJ318840CL CES 01     N-1       ZZJ318840     0.00000
# 219583       ZZJ318840CL CES 01     N-4       ZZJ318840     0.00000
# 219584            PD15CL CES 01     N-4            PD15  1149.00000
#
#           fc_anas  Venta     Prom.  Total instock  MAPE_AJUSTADO         ERP  \
# ...

# %%
df_final_2 = pd.concat([df_final, df_2])

# %%
df_final.shape
# Out:
# (2552401, 25)

# %%
df_2.shape
# Out:
# (219585, 26)

# %%
df_final_2['Mes'] = pd.to_datetime(df_final_2['Mes'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_final_2['Mes'] = pd.to_datetime(df_final_2['Mes'])
#
# File c:\Users\lravlic\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1108, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1106             result = arg.tz_localize("utc")
#    1107 elif isinstance(arg, ABCSeries):
# -> 1108     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1109     if not cache_array.empty:
#    1110         result = arg.map(cache_array)
#
# File c:\Users\lravlic\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# ...

# %%
df_consolidado.to_parquet('consolidado_fc_error.parquet')

# %%
df_final_2
# Out:
#                            ID2 Periodo           UE_2           fc    fc_anas  \
# 0          B45A512L0BCL CES 01     N-1     B45A512L0B     2.639339   2.639339
# 1          768510545RCL CES 01     N-1     768510545R     0.111111   0.111111
# 2          768510545RCL FLOTAS     N-1     768510545R     0.032782   0.032782
# 3          769523741RCL CES 01     N-1     769523741R     0.213110   0.213110
# 4       8202100XKZ20ACL CES 01     N-1  8202100XKZ20A     0.000000   0.000000
# ...                        ...     ...            ...          ...        ...
# 219580      ZZJ118110CL CES 01     N-1      ZZJ118110    40.112900  40.112900
# 219581      ZZJ118110CL CES 01     N-4      ZZJ118110    33.970960  33.970960
# 219582      ZZJ318840CL CES 01     N-1      ZZJ318840     0.000000   0.000000
# 219583      ZZJ318840CL CES 01     N-4      ZZJ318840     0.000000   0.000000
# 219584           PD15CL CES 01     N-4           PD15  1149.000000   0.000000
#
# ...
